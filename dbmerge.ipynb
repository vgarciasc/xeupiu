# %%
import openai
import pandas as pd
from tqdm.notebook import tqdm
from config import CONFIG

openai.organization = CONFIG["translation"]["openai"]["organization"]
openai.api_key = CONFIG["translation"]["openai"]["api_key"]

# %%
csv1 = pd.read_csv(f"data/texts/database_text_v2.csv", sep=";")
csv2 = pd.read_csv(f"data/texts/Ayako - Macgregor Playthrough 1/database_text_v2.csv", sep=";")
csv3_output_name = f"data/texts/database_text_1.csv"

csv1_new = csv1[~csv1["Japanese text"].isin(csv2["Japanese text"])]
csv2_new = csv2[~csv2["Japanese text"].isin(csv1["Japanese text"])]

csv2_new = csv2_new[~csv2_new['Japanese text'].str.contains("\?")]
csv2_new['English text'] = csv2_new['English text'].str.replace("\"", "")
csv2_new.drop_duplicates(subset=['Character name', 'Japanese text'], keep='first', inplace=True)
csv2_new.dropna(subset=['Character name'], inplace=True)
csv2_new
# Out:
#      Character name                                      Japanese text  \
# 3716        <PNAME>                                           『<DATE>。
# 3717        <PNAME>                                               『Ｂ型。
# 3718           none                                          データセーブ中です
# 3721        <PNAME>                               『えーと、アイスつてどういう意味かなあ。
# 3722          Himoo  「それはね、インサーキットエミュレータといつて開発するターゲットを実環境に近い状態でリアルタ...
# ...             ...                                                ...
# 4162           none        『この絵、片桐さんに似てない。』『この絵、奇麗だと思わない？』『あの人、奇麗だな⋯。』
# 4163           none                          大学に試験を受けに行くやめて、就職試験を受けに行く
# 4164           none                        ―流大学を受験する二流大学を受験する三流大学を受験する
# 4166         Yoshio                               「実は、未緒と付き合うことになつたんだ。
# 4167       Kisaragi                                     「さぁ、好雄君行きましょう。
#
#                                            English text
# 3716                                            <DATE>.
# 3717                                            Type B.
# 3718                           Data saving in progress.
# 3721               Let's see, what does ice cream mean?
# 3722  It is an in-circuit emulator, which is a devic...
# ...                                                 ...
# 4162  This picture doesn't look like Katagiri-san. D...
# 4163  Stop going to college to take exams and go tak...
# 4164  -Take a second-rate universityTake a third-rat...
# 4166                  Actually, I'm going out with Mio.
# 4167                         Come on, Yoshio, let's go.
#
# [373 rows x 3 columns]

# %%
def line_is_incomplete(row):
    return (sum(csv1[csv1['Character name'] == row['Character name']]['Japanese text'].str.startswith(row['Japanese text'])) > 0 or 
            sum(csv2_new[csv2_new['Character name'] == row['Character name']]['Japanese text'].str.startswith(row['Japanese text'])) > 1)

csv2_new = csv2_new[~csv2_new.apply(line_is_incomplete, axis=1)]
csv2_new
# Out:
#      Character name                                      Japanese text  \
# 3716        <PNAME>                                           『<DATE>。
# 3717        <PNAME>                                               『Ｂ型。
# 3721        <PNAME>                               『えーと、アイスつてどういう意味かなあ。
# 3722          Himoo  「それはね、インサーキットエミュレータといつて開発するターゲットを実環境に近い状態でリアルタ...
# 3723        <PNAME>                                     『あ、ありがとう。えーと⋯。
# ...             ...                                                ...
# 4162           none        『この絵、片桐さんに似てない。』『この絵、奇麗だと思わない？』『あの人、奇麗だな⋯。』
# 4163           none                          大学に試験を受けに行くやめて、就職試験を受けに行く
# 4164           none                        ―流大学を受験する二流大学を受験する三流大学を受験する
# 4166         Yoshio                               「実は、未緒と付き合うことになつたんだ。
# 4167       Kisaragi                                     「さぁ、好雄君行きましょう。
#
#                                            English text
# 3716                                            <DATE>.
# 3717                                            Type B.
# 3721               Let's see, what does ice cream mean?
# 3722  It is an in-circuit emulator, which is a devic...
# 3723                             Oh, thank you. Well...
# ...                                                 ...
# 4162  This picture doesn't look like Katagiri-san. D...
# 4163  Stop going to college to take exams and go tak...
# 4164  -Take a second-rate universityTake a third-rat...
# 4166                  Actually, I'm going out with Mio.
# 4167                         Come on, Yoshio, let's go.
#
# [338 rows x 3 columns]

# %%
def translate_openai(desc, with_character=True):
    completion = openai.ChatCompletion.create(
        model="gpt-4o",
        messages=[
            {"role": "system",
             "content": f"""You are a japanese translator. The user will give you a CSV in the format:
{'CHARACTER NAME;' if with_character else ''}JAPANESE TEXT
Your job is to reply with the following:
{'CHARACTER NAME;' if with_character else ''}JAPANESE TEXT;ENGLISH TEXT
For example, the user gives you
{'<PNAME>;' if with_character else ''}『サンキュー。
You reply with
{'<PNAME>;' if with_character else ''}『サンキュー。;Thank you."""},
            {"role": "user", "content": desc},
        ]
    )
    print(f"Tokens used: {completion.usage.total_tokens}")
    return completion.choices[0].message['content']

def process_batch_id(df, id, batch_size=50):
    _df = df.iloc[id:].head(batch_size)
    if "Character name" in _df.columns:
        batch_jp_str = '\n'.join((_df["Character name"] + ";" + _df["Japanese text"]).values)
    else:
        batch_jp_str = '\n'.join(_df["Japanese text"].values)
    translation = translate_openai(batch_jp_str, with_character="Character name" in _df.columns)
    return translation

def translate_dataframe(df):
    batch_size = 50
    
    translation_full = []
    for batch_id in tqdm(range(0, len(df), batch_size)):
        translation = ""
    
        n_tries = 0
        while n_tries < 5:
            try:
                translation = process_batch_id(df, batch_id, batch_size)
                translation_df = pd.DataFrame([x.split(";") for x in translation.split("\n")])
                translation_full.append(translation_df)
                break
            except:
                n_tries += 1
        
        print(f"Batch {batch_id}: {translation}")
    
    return pd.concat(translation_full)    

csv2_new_translated = translate_dataframe(csv2_new)
csv2_new_translated = csv2_new_translated.iloc[:, :len(csv2_new.columns)]
csv2_new_translated.columns = csv2_new.columns
csv2_new_translated
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Tokens used: 2783
# Batch 0: <PNAME>;『いや、別に用はないんだけどなんとなくね。;No, I don't really have anything to do, it's just for some reason.
# <PNAME>;（ふつ、俺としたことが、少し迷つてしまつたぜ。）;Geez, I hesitated a bit for someone like me.
# Katagiri;「<PNICKNAME>。私に、何か用？;Do you need something from me, <PNICKNAME>?
# <PNAME>;『‥‥‥。;......
# Kisaragi;「もう、すつかり春ですね。;It's already completely spring, isn't it?
# none;￣―――――――――――――――――;――――――――――――――――――
# Kagami;「あら、<PSURNAME>君今帰りかしら？;Oh, are you going home now, <PSURNAME>?
# Asahina;「<PNAME>君？何？どうしたの？;Hey, <PNAME>? What's up? What's wrong?
# none;朝日奈;Asahina
# Asahina;「じゃあ、帰ろ。<PNAME>君。;Alright then, let's go home, <PNAME>.
# Kagami;「<PSURNAME>君？今日は、電話ばつかり⋯。もてすぎるのも、困り物よね。で、何の用かしら？;Hey, <PSURNAME>? You've been on the phone all day... Being too popular is troublesome, right? So, what do you need?
# Kagami;「<PSURNAME>君？今日は、電話ばつかり⋯。もてすぎるのも、困り物よねで、何の用かしら？;Hey, <PSURNAME>? You've been on the phone all day... Being too popular is troublesome, right? So, what do you need?
# Kagami;「ねぇ、私に似合うネックレス、探して下さる？;Hey, can you help me find a necklace that suits me?
# Kagami;「あら？なかなかいいじゃない。;Oh? That's pretty good.
# Kagami;「<PSURNAME>君。それじゃ、失礼するわ。;Okay, <PSURNAME>. I'll be off then.
# Himoo;「もう、上映時間ね。;It's already showtime.
# Himoo;「それ程でもないわね。;It's not that much.
# <PNAME>;『そ、そう⋯。ありがとう。;Y-yeah... Thank you.
# <PNAME>;『朝日奈さん。どうしたの？;Asahina-san. What's up?
# Asahina;「ラッキー。ゲームセンター行こうよ。;Lucky! Let's go to the game center.
# Asahina;「うん、それでいいよ。それじゃ、今度の日曜日が楽しみ。;Yeah, that's fine. I'm looking forward to this coming Sunday.
# Asahina;「じゃあ、そろそろ中に入ろうよ。;Okay, let's head inside soon.
# Saotome;「<PSURNAME>さんちょつと聞きたいんですけど⋯。;Hey, <PSURNAME>, there's something I'd like to ask...
# Saotome;「いいわよーだ。ふん、お兄ちゃんと行くもん。;Fine, I'll just go with my brother. Hmph.
# Mikihara;「<PSURNAME>君。御用は何ですか？;Hey, <PSURNAME>. What do you need?
# Mikihara;「は、はい。そうですね。;Y-yes. That's right.
# Mikihara;「あの⋯。イルカのショー。面白かつたですね。;Um... The dolphin show was fun, wasn't it?
# Mikihara;「そ、そうですね。私もそう思います。;Y-yeah, I think so too.
# Mikihara;「<PSURNAME>君あの⋯。―緒に⋯。;Hey, <PSURNAME>... Together...
# <PNAME>;（それじゃ、遊園地で、優美ちゃんを待つか。）;Alright, let's wait for Yuumi-chan at the amusement park.
# Saotome;「これ、誕生日プレゼントです。;This is your birthday present.
# <PNAME>;『ありがとう、嬉しいよ。;Thank you, I'm happy.
# <PNAME>;（今日は、詩織とデートだ）（今日は、部活の練習試合だ）;Today is a date with Shiori. (Today there's a club practice match.)
# none;「テニス部に入部した。;I joined the tennis club.
# <PNAME>;（今日の練習は、非常にハードだ⋯。何だか目まいが⋯。）;Today's practice is really tough... I feel kind of dizzy...
# <PNAME>;『も、もう、駄目だ。;I'm at my limit.
# <PNAME>;（あぁ、俺はどうしたんだろう⋯。）;Ah, what's wrong with me...?
# Kiyokawa;「ほら、目を覚ませ。;Hey, wake up.
# <PNAME>;『うわ。つめてぇ。;Whoa. That's cold.
# Kiyokawa;「やつと気がついたみたいだな。;Looks like you finally came to.
# <PNAME>;『俺、練習してて⋯。あれ、記憶がないぞ。;I was practicing... Huh, I don't remember anything.
# Kiyokawa;「これぐらいの練習でへばるなんて、軟弱なんじゃないの？;Getting worn out from practice like this, aren't you a bit weak?
# <PNAME>;『介抱してくれたんだ。ありがとう⋯。あつ、清川さん。;You took care of me. Thank you... Oh, Kiyokawa-san.
# Kiyokawa;「私の事、知つてるの？;You know about me?
# <PNAME>;『当然。水泳部にいる人はみんな知つてるつて。（彼女は、清川望。超高校級の女スイマーだ。）;Of course. Everyone in the swim club knows her. (She's Nozomi Kiyokawa, a super high school-level female swimmer.)
# Kiyokawa;「君だけ私の名前を知つていて、私が名前を知らないのは、不公平だね。;It's unfair if you know my name and I don't know yours.
# <PNAME>;『あつ、ごめん。俺、<PNAME> <PSURNAME>。よろしく。;Oh, sorry. I'm <PNAME> <PSURNAME>. Nice to meet you.
# Kiyokawa;「よろしくね。それじゃ、十分休んだら、練習に戻つて来いよ。;Nice to meet you. Well then, once you've rested enough, come back to practice.
# <PNAME>;（やつたぁ。あの有名な清川さんと、話しちゃつたよ。これからの部活が楽しみだぜ。）;I did it! I talked with the famous Kiyokawa-san. I'm really looking forward to club activities from now on.
# <PNAME>;（あーあ、今日も―日疲れたなぁ。）;Ah, I'm exhausted from today as well.
# Tokens used: 2555
# Batch 50: Koshiki;「あーつ⋯、あぶな⋯。;Ah⋯, dangerous⋯.
# none;ボカ;Boka
# Koshiki;「あら、<PSURNAME>さん。本日は、何の御用でしょう？;Oh, Mr. <PSURNAME>. What brings you here today?
# Koshiki;「少々、お待ち下さい⋯。えーと⋯、その日は、別の約束があるみたいですね⋯。;Please wait a moment⋯. Um⋯, it seems I have another appointment that day⋯.
# <PNAME>;『あら、そうなんですか⋯。;Oh, really⋯.
# Koshiki;「申し訳ございません。ぜひ、御―緒したかつたのですけれども⋯。;I’m sorry. I really wanted to go with you⋯.
# <PNAME>;『気になさらないでください。それでは、この次はぜひ⋯。では、失礼いたします。;Please don’t worry about it. Then, next time for sure⋯. Well, I'll be leaving now.
# <PNAME>;（言葉うつつちゃつたよ。）;(I messed up my words.)
# Koshiki;「いいえ。私も、今、着いたところなんですよ。;No. I just got here myself.
# Koshiki;「静かな所ですねぇ。;It's a quiet place, isn't it?
# Koshiki;「そうですねぇ。では、参りましょう。;Yes, it is. Well, shall we go?
# Koshiki;「こういう所を散策するのつて、気持ちがいいですねぇ。;It feels good to stroll around places like this.
# Koshiki;「本日は、楽しく過ごせました。ありがとうございます。;I had a great time today. Thank you.
# Koshiki;「そうですねぇ。よろしいですよ。;Yes, it’s fine.
# Koshiki;「<PSURNAME>さんそれでは、そろそろ帰りましょう。;Mr. <PSURNAME>, let's get going home soon.
# none;清川;Kiyokawa
# <PNAME>;『あつ、丁度いいところに、古式さんが現れたぞ。;Ah, just at the right moment, Ms. Koshiki appeared.
# Koshiki;「おはようございます。<PSURNAME>さん。;Good morning, Mr. <PSURNAME>.
# Koshiki;「はい、私でよろしければ御―緒させて下さい。;Yes, if you don’t mind, please let me join you.
# Koshiki;「何かが始まるみたいですねぇ。;It looks like something is about to start.
# <PNAME>;『ちょうど演劇が始まるみたいだね。;It seems the play is about to start.
# Echigoya;「このたびは、;This time,
# none;「このたびは、お奉行様のおはからい、誠にありがとうございました。;We sincerely thank you for your consideration, Magistrate.
# magistrate;「なになに、あのようなこと造作もない事。;Oh, that was no trouble at all.
# magistrate;「ほう！;Ho!
# none;「ほう！わしはこの黄金色の菓子には目が無くてな！;Ho! I can’t resist this golden candy!
# none;奉行＆越後屋「はつはつはつはつは！ほつほつほつほつほ！;Magistrate & Echigoya: Ha ha ha ha ha! Ho ho ho ho ho!
# magistrate;「ど～れ、;Well then,
# none;金太郎侍「まさかりかついで金太郎！;Samurai Kintaro: Carrying a broadaxe, Kintaro!
# none;金太郎侍「勘定奉行、大橋台善！;Samurai Kintaro: Finance Magistrate, Oohashi Daizen!
# none;金太郎侍「御用材木を独占し、私腹を肥やさんとした事許し難し。この吉宗、金太郎侍として成敗いたす！;Samurai Kintaro: It’s unforgivable to monopolize official lumber for personal gain. I, Yoshimune, as Samurai Kintaro, will punish you!
# none;金太郎侍「潔く腹を切るがよい！;Samurai Kintaro: Commit seppuku with dignity!
# magistrate;「ぬぬぬぬぬつ．．．！;Nu nu nu nu nu⋯!
# teacher;「どれ、;Well then,
# none;「どれ、拙者の飛燕風来の剣のサビにしてくれるわつ！;Well then, let’s see how they stand against my Hien Fuuraiken!
# magistrate;「越後屋、何とかせい！;Echigoya, do something!
# Koshiki;「時代劇は、面白いですねぇ。;Period dramas are interesting, aren't they?
# <PNAME>;『古式さんつて、時代劇好きなんだ？;Ms. Koshiki, do you like period dramas?
# Koshiki;「そうですね。ぼーつとしていても、わかりますから。;Yes. I can understand them even when I'm spaced out.
# <PNAME>;『そ、そうなんだ。それじゃあ、そろそろ、帰ろうか？;Oh, I see. Then, shall we head back soon?
# Koshiki;「そうですね。もう帰りましょう。;Yes, let’s go home now.
# <PNAME>;（あつ、古式さんがいるぞ。）;(Ah, there’s Ms. Koshiki.)
# Koshiki;「<PSURNAME>さん今、お帰りですか？;Mr. <PSURNAME>, are you heading home now?
# Koshiki;「それでは、失礼いたします。;Well then, I'll be excusing myself.
# <PNAME>;『おーい、古式さん。;Hey, Ms. Koshiki.
# Koshiki;「そうですね。よろしいですよ。―緒に帰りましょう。;Yes, it’s fine. Let’s go home together.
# <PNAME>;（俺は、古式さんと、楽しく下校した。）;(I had a pleasant walk home with Ms. Koshiki.)
# Koshiki;「申し訳ございません。どうやら、ゆつくり歩きすぎたようですね。;I'm sorry. It seems I walked too slowly.
# Koshiki;「そろそろ上映時間ですね。;It's almost showtime now.
# <PNAME>;『あそこが空いてるよ。早く早く。;There’s an open spot over there. Hurry, hurry.
# Tokens used: 2426
# Batch 100: Koshiki;「ちょつと、待つてください。;Just a moment, please.
# Koshiki;「そうですねぇ。面白かつたですねぇ。;Yes, that was interesting.
# Koshiki;「本日は、とても楽しく過ごせました。ありがとうございます。;I had a very enjoyable time today. Thank you.
# Koshiki;「はい。よろしいですよ。;Yes. It's alright.
# Koshiki;「こういう所は、大変落ち着けますねぇ⋯。;Places like this are very calming...
# <PNAME>;（幼少の頃から聴いているクラシックが好み。ということを聞き出した。）;(I found out that she has a preference for classical music since childhood.)
# <PNAME>;『よし、リストバンドを、プレゼントしよう。;Alright, I'll give her a wristband as a present.
# Kiyokawa;「ふーん。ありがたく使わせてもらうよ。;Hmm. I'll gratefully use it.
# none;東風高校の勝ち！きらめき高校の負け;Toukaze High School wins! Kirameki High School loses!
# Koshiki;「それにしても、凍えてしまいそうですね。;Even so, it looks like we'll freeze.
# Koshiki;「そういたしましょう。;Let's do that.
# Koshiki;「素敵な絵がたくさんありますね。;There are many wonderful paintings.
# Koshiki;「奇麗ですねぇ。;It's beautiful.
# Koshiki;「<PSURNAME>さんこんばんは。招待されていたのですね。;<PSURNAME>, good evening. You've been invited, right?
# <PNAME>;『古式さんも、来てたのか。;Koshiki, you're here too.
# Koshiki;「申し訳ありませんが、用がありますので、少々、失礼いたします。;I'm sorry, but I have something to do, so please excuse me for a moment.
# Kiyokawa;「あつ、<PNICKNAME>招待されてたんだ。;Oh, <PNICKNAME> was invited too.
# none;しばらく清川さんと話し込んだ;Talked with Kiyokawa for a while.
# Kiyokawa;「悪いけど、そろそろ行くよ。;Sorry, but I'll be going soon.
# none;古式さんのプレゼントだ！うわぁ、マフラーだ。手編みかな？;It's Koshiki's present! Wow, it's a scarf. Is it hand-knitted?
# <PNAME>;『よし、それじゃあ古式さんの家に電話してみるか。;Alright, let's give Koshiki a call at her house.
# Koshiki;「はい、古式ですけれども。;Yes, this is Koshiki.
# Koshiki;「<PSURNAME>さん。新年明けまして、おめでとうございます。;<PSURNAME>, Happy New Year.
# <PNAME>;『ところで、古式さん。今、暇かな？;By the way, Koshiki, are you free now?
# Koshiki;「そうですねぇ。暇ですよ。;Yes, I'm free.
# Koshiki;「はい、わかりました。神社の前ですね。;Yes, understood. In front of the shrine, right?
# <PNAME>;『まだ、古式さんは来てないみたいだな。;It seems that Koshiki hasn't arrived yet.
# Koshiki;「申し訳ございません。お待たせいたしました。;I'm terribly sorry for making you wait.
# <PNAME>;『古式さん。晴着を着てきたんだ。;Koshiki, you wore a kimono for this.
# Koshiki;「せつかくの、お正月ですから。;Since it's New Year's after all.
# Koshiki;「そうですか。誉めていただいて、ありがとうございます。;Is that so? Thank you for the compliment.
# Koshiki;「それでは、ゆつくりと、参りましょう。;Then, let's take our time and go.
# <PNAME>;『古式さんは、何をお願いしたの？;What did you wish for, Koshiki?
# Koshiki;「人に言いますと、願いがかなわなくなると、言われていますから。;They say if you tell others, your wish won't come true.
# Koshiki;「そうですね。参りましょう。;Yes, let's go.
# Koshiki;「私は、大吉でした。;I got great fortune.
# <PNAME>;『俺は大凶だつたよ。;I got the worst fortune.
# Koshiki;「そうですか。それでは、木に結ばない方がいいですね。;Is that so? Then, you shouldn't tie it to the tree.
# Koshiki;「今年もいい年になるといいですねぇ。;I hope this year will be a good one too.
# Koshiki;「あら、<PNAME>さん。本日は、何の御用でしょう？;Oh, <PNAME>. What brings you here today?
# Koshiki;「<PNAME>さん今、お帰りですか？;Are you on your way home now, <PNAME>?
# Koshiki;「奇麗なお魚が、たくさんいますねぇ。;There are many beautiful fish, aren't there?
# Koshiki;「本当に、その通りですねぇ。;That's really true.
# Koshiki;「<PNAME>さんそれでは、そろそろ帰りましょう。;Then, <PNAME>, shall we head home soon?
# Koshiki;「奇麗な池ですねぇ。よろしければ、少し休みませんか？;It's a beautiful pond. Would you like to take a little break?
# Koshiki;「疲れていましたので、嬉しいですねぇ。;I'm happy because I was tired.
# <PNAME>;『そう言えば、もうすぐテストだよ。;By the way, we have a test coming up soon.
# Koshiki;「そうでしたか？すつかり忘れていました。;Was that so? I completely forgot.
# <PNAME>;『そ、そう。（うらやましい性格だな。）;I see. (Such an enviable personality.)
# Koshiki;「そうですねぇ。こんな場面がありましたねぇ。;Yes, we had a moment like this, didn't we?
# Tokens used: 2531
# Batch 150: Koshiki;「少々前にも、ここに来たことがありますね。;I was here a little while ago too.
# <PNAME>;『そ、そうかな？（しまつた、もうちょつとチェックしとくんだつた。）;Oh, really? (Oops, I should have checked better.)
# Koshiki;「はい。何か御用ですか？;Yes. Do you need anything?
# Koshiki;「そう言えば、今日は、ホワイトデーでしたね。わざわざ、ありがとうございました。;Speaking of which, today is White Day, isn't it? Thank you for going out of your way.
# Koshiki;「こんにちは、<PNAME>さん。;Hello, <PNAME>.
# <PNAME>;『あつ、古式さん。見に来てくれたんだ。;Oh, Koshiki. You came to see me.
# Koshiki;「頑張つて下さいね。私も、あちらで見ておりますので。;Do your best. I'll be watching from over there.
# <PNAME>;『うん、じゃあ後で。;Alright, see you later.
# Koshiki;「大変素晴らしいご活躍でしたね。私も嬉しいです。;You did an amazing job. I'm very happy for you.
# <PNAME>;『古式さんの応援のおかげだよ。;It's thanks to your support, Koshiki.
# Koshiki;「そうですか？それでは、また参りましょう。;Is that so? Well then, shall we go again?
# <PNAME>;『古式さん。どうしたの？;Koshiki. What's wrong?
# Koshiki;「よろしければ、買い物に付き合つていただけませんか？;Would you mind accompanying me for shopping if you'd like?
# Koshiki;「はい、それで結構です。それでは、楽しみにしておりますので。;Yes, that would be fine. I'm looking forward to it.
# Koshiki;「そんな事はございませんよ。私も、今着いたばかりですから。;It's not like that at all. I just arrived too.
# Koshiki;「どちらへ、参りましょうか？;Where shall we go?
# Koshiki;「よろしいですね。参りましょう。;That sounds good. Let's go.
# Koshiki;「この服、素敵ですねぇ。;This dress is lovely, isn't it?
# Koshiki;「本当ですねぇ。それでは、両方とも、買うことにいたしましょう。;Really, isn't it? Then let's buy both.
# Koshiki;「本日は、誠にありがとうございました。;Thank you very much for today.
# Koshiki;「それでは、帰りましょう。;Shall we head home then?
# <PNAME>;（植物園かあ。そういえば詩織が夜に羊を数える癖があつたな。どこかで聞けたんだけど。）;(The botanical garden, huh. Speaking of which, Shiori used to count sheep at night. I heard it somewhere.)
# Koshiki;「イルカさんつて、すごいですねぇ。;Dolphins are amazing, aren't they?
# Nijino;「今日は、まあ楽しかつたわ⋯。;Today was fun, I guess...
# <PNAME>;『そ、そう。良かつた。;Oh, I see. That's good.
# Koshiki;「運動は、苦手ですけれども、楽しみですねぇ。;I'm not good at exercise, but I'm looking forward to it.
# <PNAME>;『うん。楽しみだね。;Yeah. It'll be fun.
# Saotome;「何？優美に用？;What? Do you need me?
# Saotome;「やつたー。開けてもいい？;Yay! Can I open it?
# Saotome;「わーつ。ありがとう。;Wow. Thank you.
# Koshiki;「大変お上手だとお聞きしましたが⋯。;I heard you're very skilled...
# Koshiki;「本当に、そうですねぇ。;That's really true, isn't it?
# <PNAME>;『よし、オルゴールを、プレゼントしよう。;Alright, I'll give her a music box as a present.
# <PNAME>;『あつ、古式さん！;Oh, Koshiki!
# Koshiki;「まあ、<PNAME>さん。何の御用でしょうか？;Oh, <PNAME>. How can I help you?
# Koshiki;「そう言えば、今日は、私のお誕生日でしたね。開けてもよろしいでしょうか？;Oh, today is my birthday, isn't it? May I open it?
# Koshiki;「これは、また結構なものを頂戴いたしまして⋯。我が家の家宝にいたします。;This is quite a gift... I'll make it a family treasure.
# none;第三高校の勝ち！きらめき高校の負け;Third High School wins! Kirameki High School loses.
# <PNAME>;『水族館の前でいいかな？;Is it okay in front of the aquarium?
# Koshiki;「それでは、何に乗りましょうか？;Then what should we ride?
# Koshiki;「これは、落ち着けるので好きです。;I like this because it's relaxing.
# Koshiki;「素敵な眺めでしたねぇ。;It was a beautiful view, wasn't it?
# Koshiki;「何かついてましたか？;Was something on me?
# Koshiki;「気に入つていただけるかどうかわかりませんが、よろしければ、どうぞ。;I'm not sure if you'll like it, but if you don't mind, please take it.
# Koshiki;「気に入つていただけるかどうわかりませんが、よろしければ、どうぞ。;I'm not sure if you'll like it, but if you don't mind, please take it.
# Koshiki;「はい、お誕生日の、贈り物です。;Yes, it's a birthday gift.
# <PNAME>;（古式さんにプレゼントをもらえるなんて、俺は幸せ者だー！）;(To receive a present from Koshiki, I'm so lucky!)
# Koshiki;「私もお魚になつて、―日中、ぼーつと泳いでみたいですねぇ。;I also wish I could become a fish and swim absent-mindedly all day.
# Koshiki;「そう言えば、泳げませんねぇ。;Come to think of it, I can't swim.
# Koshiki;Ｉこ;I see.
# Tokens used: 2674
# Batch 200: <PNAME>;（それじゃ、動物園で、優美ちゃんを待つか。）;(Well then, shall we wait for Yumi-chan at the zoo?)
# Saotome;「今見てきた、コアラ、とーつても可愛かつた。;The koalas I just saw were soooo cute.
# Saotome;「優美、よくわかんなーい。;Yumi, I don't get it.
# Koshiki;「すごく賑やかですねぇ。;It's very lively, isn't it?
# Koshiki;「いいものが取れるといいですねぇ。;I hope we get something good.
# <PNAME>;『取れたら古式さんにあげるね。;If I do, I'll give it to you, Koshiki-san.
# Koshiki;「あら？もう、終わりなのですか？;Oh? Is it over already?
# Kiyokawa;「そういう時は、基本からやり直してみると、いいと思うよ。私もそうだつたから。;At times like that, it's good to start over from the basics. That's what I did.
# <PNAME>;『基本からねぇ⋯。清川さんにもそういう時があるんだ。;From the basics, huh... Even Kiyokawa-san has times like that.
# Kiyokawa;「私だつて、スランプのときぐらいあるわよ。;Even I have a slump sometimes.
# <PNAME>;『そりゃそうだよね。でも、参考になつたよ。ありがとう。;That's true. But you were helpful. Thank you.
# Kiyokawa;「水泳の事だつたら、いつでも相談してね。及ばずながら、力になるわ。;If it's about swimming, feel free to ask me anytime. I'll help as much as I can.
# <PNAME>;『ごめんね。自分の練習も忙しいのに。;Sorry. You must be busy with your own training too.
# Kiyokawa;「別にいいのよ。それじゃ、頑張つてね。;It's totally fine. Well then, do your best.
# Kiyokawa;「みんなごめん。勘弁して。;Everyone, sorry. Please bear with me.
# <PNAME>;（清川さんが、今朝の食事を作つたのか⋯。）;Did Kiyokawa-san make this morning's meal...?
# Kiyokawa;「ほら、あんまり料理なんて作らないから。いや、悪かつたと思つてるよ。;You see, I don't usually cook. I feel bad about it.
# <PNAME>;（さあ、練習再開だ。清川さんは、あまり気にしてないみたいだ。）;Alright, back to practice. It seems Kiyokawa-san isn't too bothered.
# Nijino;「それじゃ、着替えて来るね。;Okay, I'll go change.
# Nijino;「あんまり焼きすぎると痛くなつちゃうよ。;If you burn it too much, it'll hurt.
# Nijino;「そうそう。急に焼くのは良くないからね。;Yeah, yeah. It's not good to burn it suddenly.
# Koshiki;「野球のチケットがありますので、よろしければ、ご―緒しませんか？;I have baseball tickets, so if you like, would you join me?
# Koshiki;「それでは、そろそろ中に入ることといたしましょう。;Well then, shall we go inside soon?
# Koshiki;「野球つて、観ていて面白いのですか？;Is baseball fun to watch?
# Koshiki;「そうですか。私も観るだけなら、好きですけれど。;I see. I like watching it too, though.
# Koshiki;「<PNAME>さん、おはようございます。;Good morning, [PNAME].
# <PNAME>;『あつ、古式さん、おはよう。;Oh, Koshiki-san, good morning.
# Koshiki;「御―人で、行かれるのですか？;Are you going alone?
# <PNAME>;『うーん、どうしよう。;Hmm, what should I do?
# Koshiki;「よろしければ、御―緒させていただけませんか？;If you don't mind, could I join you?
# Koshiki;「私も、疲れてしまいました。本当に、広いですね。;I'm tired too. It really is spacious.
# Koshiki;「そうですね。そろそろ戻りましょう。;That's true. Let's head back soon.
# Koshiki;「はい、よろしいですよ。それでは、どこで待ち合わせしましょうか？;Sure, that's fine. So, where shall we meet?
# <PNAME>;『それじゃ、ホテルのロビーでいいかな？;Then, is the hotel lobby okay?
# Koshiki;「あつ、こんばんわ。;Ah, good evening.
# <PNAME>;『ん？誰だろう。でも、この声は⋯？;Hmm? Who could it be? But this voice is...?
# Koshiki;「申し訳ありません。少々、のぼせてしまいまして⋯。;I'm sorry. I got a bit dizzy...
# <PNAME>;『こ、古式さんなの？全然別人のようだ。;Is that you, Koshiki-san? You seem like a completely different person.
# Koshiki;「そうでしょうか？;Do I?
# <PNAME>;『お風呂行つて来たんだ。湯加減はどうだつた？;You went to the bath, right? How was the water temperature?
# Koshiki;「結構な、湯加減でございました。ですけど⋯。;The water temperature was quite nice. But...
# <PNAME>;『ですけど？;But?
# Koshiki;「少々、狭いお風呂でございました。;The bath was a bit small.
# <PNAME>;『あれ？大浴場以外にお風呂つてあつたかな？;Huh? Was there a bath other than the large public one?
# Koshiki;「見た所、５０人程しか、御―緒にできない広さでしたけど⋯。;It seemed like only about 50 people could fit together...
# <PNAME>;『！？;!?
# Koshiki;「お父様に電話する時間なので、それでは、失礼します。;It's time to call my father, so if you'll excuse me.
# Koshiki;「お父様に電話する時間なのでそれでは、失礼します。;It's time to call my father, so if you'll excuse me.
# Koshiki;「遅くなつてしまいまして、申し訳ございません。;I'm sorry for being late.
# <PNAME>;『いいよ、俺も今、来たところだから。;It's okay, I just got here too.
# Tokens used: 2771
# Batch 250: Koshiki;「そうでございますか。それでは、早速参りましょう。;Is that so? Well then, let's get going right away.
# Koshiki;「はい、私もお父様に何か買つていかなくては⋯。あれは⋯？;Yes, I should buy something for my father too... What is that...?
# <PNAME>;『ふう、勝つたぜ。古式さんは、無事だつたかな。;Phew, we won. I wonder if Koshiki was alright.
# <PNAME>;『うん、全然平気。;Yeah, no problem at all.
# Koshiki;「かばつていただいて、本当にありがとうございました。;Thank you so much for protecting me.
# <PNAME>;『礼なんていいよ。じゃあ、そろそろ帰ろうか。;Don't mention it. Well then, shall we head home?
# Koshiki;Ｉ―;I—
# Koshiki;「―体、どうしたら真ん中に行くのでしょうね。;—I wonder how I can get to the middle.
# Koshiki;「ふぉーむですか。では、もう―度。;Form, is it? Well then, one more time.
# Koshiki;「<PNAME>さん。おはようございます。;<PNAME>, good morning.
# Koshiki;「御―人で、見学なさるのですか？;Are you here sightseeing by yourself?
# Koshiki;「お父様が来られないものですから、よろしければ、御―緒させていただけませんか？;My father can't come, so if it's alright, could I join you?
# Koshiki;「それでは、どこへ参りましょうか？;So, where shall we go?
# Koshiki;「美術部はすごいですね。;The art club is amazing, isn't it?
# <PNAME>;『どうしたの？古式さん。;What's wrong, Koshiki?
# Koshiki;「ちょつとびつくりしちゃいました。;I was a little surprised.
# <PNAME>;『えつ、何をやつてるの？よく見えないよ。;Huh, what are they doing? I can't see well.
# Koshiki;「そうですね。私が邪魔しているみたいですねぇ。;I guess I'm in the way, aren't I?
# <PNAME>;『‥‥‥‥‥。（そう思つてるのなら、早く退いてくれ。）;...... (If you think that, then please move soon.)
# Koshiki;「それでは、私は外で待つていますので、ごゆつくりどうぞ。;In that case, I’ll wait outside, so please take your time.
# <PNAME>;『おおおおおおおつ！（こんないいことをしていたのか。）;Whoa! (They were doing something this great?)
# <PNAME>;（古式さんが待つてるのに、いつまでも見てるわけにはいかないな。）;(With Koshiki waiting, I can't keep watching forever...)
# Nijino;「そうですね。それじゃ、始めましょう。;That's right. Well then, let's start.
# Koshiki;「ついつい、たくさん買つてしまいました。;I ended up buying a lot.
# Koshiki;「そうですか。それでは、お願いいたします。;I see. Then, please do so.
# Saotome;「動物園つてペットがたくさんいるようで楽しいね。;Zoos are fun because they have lots of pets, don't they?
# Saotome;「それじゃあ、いろんな動物見に行こう。;Let's go see various animals then.
# <PNAME>;（ん？如月さん泣いてるのか？）;(Hmm? Is Kisaragi crying?)
# Kisaragi;「くすん⋯。可哀想⋯。;Sniff... That's so sad...
# <PNAME>;（如月さんて、感銘を受けやすいんだな⋯。）;(Kisaragi is easily moved, huh...)
# Kisaragi;「今の映画、とても良かつたですね。;That movie just now was really good, wasn't it?
# <PNAME>;『そういえば、如月さん。途中で泣いてたでしょう。;By the way, Kisaragi, you were crying during it, weren't you?
# Kisaragi;「えつ⋯。見てたんですか？恥ずかしい⋯。;Ah... You saw? How embarrassing...
# <PNAME>;『眼鏡を外した顔、可愛かつたよ。;You looked cute without your glasses.
# Kisaragi;「そんな、可愛いだなんて⋯。私⋯、眼鏡をしてないほうがいいですか？;C-cute, you say... Do I look better without glasses?
# Kisaragi;「そうですか？お世辞でも、嬉しいです⋯。;Really? Even if you're just flattering me, I'm happy...
# Mysterious Woman;「試合、頑張つてね。それじゃ⋯;Do your best in the match, okay? Well then...
# <PNAME>;『お～い。（―応、応援に来てくれたのかな？）;Hey! (She came to support me, maybe?)
# none;宮前山高校の勝ち！きらめき高校の負け;Miyamae High School wins! Kirameki High School loses.
# Koshiki;「とても奇麗ですねぇ。;It’s very beautiful, isn’t it?
# <PNAME>;『古式さん。ボーッとしてないで、座ろうよ。;Koshiki, don't just space out, let's sit down.
# Koshiki;「星を見てると、何だか心が静かになつていくみたいです。;Looking at the stars somehow calms my heart.
# Koshiki;「そうなんですか。そう思うと、もつと神秘的ですねぇ⋯。;Is that so? Thinking that way makes it even more mysterious...
# Koshiki;「スキーに来るのは初めてなんです。;This is my first time coming to ski.
# <PNAME>;『そ、そうなんだ？それじゃあ、スキーウェアその他―式は⋯？;Oh, is that so? Then what about ski wear and other things...?
# Koshiki;「今日のために、お父様に買つていただきました。;My father bought them for me just for today.
# <PNAME>;『そ、そう⋯。（金持ちだなぁ。）;I see... (She's rich...)
# Koshiki;「このブランコみたいな、リフトと言うものに乗るんですね。;We get on something called a lift, which is like a swing, don't we?
# <PNAME>;『こ、古式さん。初めてなら、下で練習したほうが⋯。;K-Koshiki, if it's your first time, maybe you should practice at the bottom...
# Koshiki;「楽しみですねぇ。さあ、乗りましょう。;I'm looking forward to it. Now, let's ride.
# Tokens used: 2910
# Batch 300: <PNAME>;『さあ、乗るよ。;Come on, let's get on.
# <PNAME>;『だ、大丈夫？古式さん。ほら、手に掴まつて。;A-are you okay, Koshiki? Here, hold my hand.
# Koshiki;「び、びつくりしました。リフトつて乗るのが難しいんですね。;I-I was surprised. It's difficult to ride the lift, isn't it?
# <PNAME>;『そ、そうだね。（古式さんだけだつて。）;Y-yeah. (It's just Koshiki.)
# Koshiki;「それにしても、高いところまで、来てしまいましたね。;Even so, we've come to quite a high place, haven't we?
# <PNAME>;『どう？古式さん。降りれそう？;What do you think, Koshiki? Can you get down?
# Koshiki;「ちょつと、無理そうですね。下りのリフトに乗せてもらいましょう。;It seems a bit difficult. Let's take the lift down.
# <PNAME>;『リフトは下りは乗せてもらえないんだよ。;They don't allow you to ride the lift down.
# Koshiki;「そうなんですか？困りましたね。どうしましょう？;Is that so? That's troublesome. What should we do?
# <PNAME>;『転びながら、ゆつくり降りていくしかないね。;We have no choice but to slowly make our way down, even if we fall.
# Koshiki;「そ、そうですか⋯。それでは、そういたしましょう。;I-I see... Let’s do that then.
# <PNAME>;（大丈夫かな？古式さん。）;Is Koshiki going to be okay?
# <PNAME>;（やつた！古式さんと、清川さんから、年賀状をもらつたラッキー。）;Yay! I got New Year's cards from Koshiki and Kiyokawa. Lucky!
# Koshiki;「<PNAME>さん新年明けましておめでとうございます。;Happy New Year, <PNAME>-san.
# <PNAME>;『あ、古式さん。明けまして、おめでとう。晴着がいいね。;Ah, Koshiki. Happy New Year. Your kimono looks nice.
# <PNAME>;『それで、新年早々、どうしたの？;So, what's up at the very start of the new year?
# Koshiki;「よろしければ、これから初詣に行きませんか？;If it's alright with you, would you like to go for the first shrine visit of the year?
# Koshiki;「それでは、早速行きましょう。;Let’s go quickly then.
# <PNAME>;『古式さん、どうだつた？;How was it, Koshiki?
# <PNAME>;『俺は凶だつたよ。;I got a curse.
# Koshiki;「今年は、元日から良い事がありましたので、いい年になりますね。;Since something good happened right from New Year's, it'll be a good year.
# <PNAME>;『えつ、いい事つて？;What? Good thing?
# Koshiki;「―緒に初詣に来られましたから。;Because we came for the first shrine visit together.
# <PNAME>;『そ、そう。嬉しいよ⋯。;I-I see. I'm glad...
# Koshiki;「こんにちは。怪我をしないように、頑張つてくださいね。;Hello. Be careful not to get injured, alright?
# <PNAME>;『よし、拒人の星全集を、プレゼントしよう。;Alright, I'll give you the complete works of "Rejection Star."
# <PNAME>;（それじゃ、ボーリング場で、優美ちゃんを待つか。）;Then, I guess I'll wait for Yuumi-chan at the bowling alley.
# Koshiki;「すごい汗ですね。あまり無理は、しないでくださいね。;You're sweating a lot. Don't overdo it, alright?
# Koshiki;「どれも、可愛いですねぇ？;They're all cute, aren't they?
# Koshiki;「そうですか？ありがとうございます。;Is that so? Thank you.
# <PNAME>;『ああ、そうしよう。じゃあ、また今度。;Yeah, let's do that. See you next time.
# Koshiki;「<PNAME>さんこれ、お口に合うかどうかわかりませんが、よろしければ、どうぞ。;Here, <PNAME>-san, I'm not sure if it will suit your taste, but please, try it.
# <PNAME>;『あ、ありがとう。でも、随分大きなチョコだね。;Ah, thank you. But that's quite a big chocolate.
# Koshiki;「ボーッとしていて、気がついたら、たくさんのチョコを溶かしてしまいまして⋯。;I was zoning out, and before I noticed, I had melted a lot of chocolate...
# <PNAME>;『古式さんの手作りなの？;Is it handmade by you, Koshiki?
# Koshiki;「それは、開けるまでの秘密です。では、失礼いたします。;That's a secret until you open it. Well then, please excuse me.
# <PNAME>;『そ、それじゃ。（さつき溶かしてたつて言つたのになぁ⋯。）;W-well then. (She said she melted it earlier though...)
# Koshiki;「少々、見たいものがありますので、後からいらしてください。;There's something I want to see, so please come later.
# <PNAME>;『は、速い。（古式さんつてこんなに速く走れたんだ⋯。）;She's fast. (I didn't know Koshiki could run so fast...)
# <PNAME>;『古式さんは、どこに行つたんだ⋯？あつ、いた。;Where did Koshiki go...? Ah, there she is.
# <PNAME>;『古式さん、探したよ。食虫植物コーナーにいるんだもんな。;Koshiki, I was looking for you. You're in the carnivorous plant section.
# Koshiki;「ほら、見てください。面白い形をしていると思いませんか？;Look, don't you think it has an interesting shape?
# <PNAME>;『それはね、ウツボカズラと言つて、虫を食べるんだよ。;That's a pitcher plant. It eats bugs.
# Koshiki;「お父様が、殿方は食虫植物だと言つておりましたが、よくわかりませんね。;My father said gentlemen are like carnivorous plants, but I don't really understand.
# <PNAME>;『そ、それはね⋯。いいや、やめておこう。;W-well, that's... Never mind, I'll leave it be.
# Koshiki;「どうしてでしょうね？こんなに可愛いし、ふたまで付いてますよ。;I wonder why that is? They're so cute and even have lids.
# <PNAME>;『‥‥‥‥。（確かにふたは付いてるけどさ、可愛いか？）;...... (It does have a lid, but is it cute?)
# Koshiki;「見てるだけで、楽しいですねぇ。;Just watching them is fun.
# <PNAME>;『こ、古式さん。そろそろ先に行かない？;K-Koshiki, shouldn't we move on soon?
# Koshiki;「そうですねぇ。参りましょうか。;I suppose so. Shall we proceed?
# Tokens used: 2684
# Batch 350: Koshiki;「<PNAME>さん、何の御用でしょうか？;What do you need, <PNAME>?
# Koshiki;「わざわざご丁寧に、ありがとうございます。;Thank you for being so courteous.
# <PNAME>;『良かつた、喜んでもらえて。;I'm glad you are pleased.
# Koshiki;「やはり、特定の殿方にお返ししてもらうと、とても嬉しいですね。;I'm really happy to receive something back from a certain gentleman.
# Koshiki;「まぁ、奇麗な包み紙ですね。それでは、失礼いたします。;Oh, such beautiful wrapping paper. Well then, if you'll excuse me.
# <PNAME>;（なんかごまかしてたような⋯。でも、あげてよかつた。）; (It felt like she was deflecting... But I'm glad I gave it to her.)
# Nijino;「また、作りすぎちゃつて⋯。;I made too much again...
# <PNAME>;『虹野さんのお弁当ならいつでも歓迎だよ。;Nijino-san's lunch is always welcome.
# Nijino;「それじゃ今日も外で―緒に食べましょう？;Shall we eat together outside today, too?
# Nijino;「はい、どうぞ。あんまり中身は変わらないけど。;Here you go. The contents haven't changed much, though.
# Nijino;「うふ、おいしい？;Hehe, is it good?
# Fujisaki;「あーつ、もう春の香りがするね。;Ah, you can already smell the scent of spring.
# <PNAME>;『でも、古式さんとは仲良くやつていけそうかな。;But I wonder if I can get along well with Koshiki-san.
# <PNAME>;『えーと、古式さんは、二流大学に進学かぁ。古式さんは進学するのか。;Um, Koshiki-san is going to a second-rate university. Is Koshiki-san going to college?
# Koshiki;「私の歌、どうでしょうか？;How is my singing?
# Koshiki;「それは、ありがとうございます。;Thank you for that.
# Nijino;「ねぇ、見た？今のすごいプレーね。;Did you see that? That was an amazing play.
# Nijino;「本当。ちょつと感動しちゃつた。;Really. I was a little moved.
# Nijino;「あつ、<PNAME>君ちょつと聞きたいんだけど⋯。;Oh, <PNAME>-kun, can I ask you something...?
# Nijino;「よかつたら、プラネタリウムに行かない？;If you're interested, would you like to go to the planetarium?
# Saotome;「<PSURNAME>さん、いつしょに踊りたいので、こつちの輪に来ちゃいました。;<PSURNAME>-san, I wanted to dance with you, so I joined this circle.
# Nijino;「それじゃ中に入りましょう。;Then, let's go inside.
# Nijino;「奇麗ですね。それじゃ、座ろうよ。;It's beautiful, isn't it? Let's sit down.
# Nijino;「星つて神秘的だと思うな⋯。;I think stars are so mysterious...
# Nijino;「そう考えると、気が遠くなるほどの長い月日ね。;When you think about it, it's such a long, distant time.
# <PNAME>;『よし、観葉植物の鉢植えを、プレゼントしよう。;Alright, I'll give a potted plant as a present.
# none;近衛高校の勝ち！きらめき高校の負け;Konohe High School wins! Kirameki High School loses.
# Nijino;「そう⋯。あつ、別に良いの。それじゃ。;I see... Oh, it's fine. See you then.
# <PNAME>;『あ、古式さん。どうしたの？;Oh, Koshiki-san. What's up?
# Kiyokawa;「わりと⋯。はぁ、そんなもんか⋯。;Pretty much... Ah, is that so...
# <PNAME>;『今日は、イルカショーの特別イベントがあるみたいだね。;It seems there's a special dolphin show event today.
# Koshiki;「そうなんですか？それは、是非拝見してみたいですね。;Is that so? I'd definitely love to see it.
# <PNAME>;『それじゃ、行つてみよう。;Then let's go check it out.
# Koshiki;「それでは、参りましょう。;Well then, let's go.
# <PNAME>;『悪いけど、ちょつと先に行つててくれるかな？;Sorry, but could you go ahead a bit?
# Koshiki;「わかりました。それでは、待つていますので。;Understood. I'll be waiting then.
# <PNAME>;（さつきから、トイレに行きたかつたんだよね。）; (I've been wanting to go to the restroom for a while now.)
# <PNAME>;（さて、古式さんを待たせてるからな。早く行かなきゃ。）; (Now, I need to hurry since Koshiki-san is waiting.)
# none;ザッパーン;Splash!
# Koshiki;「きゃー。;Kyaa!
# <PNAME>;『こ、古式さん。大丈夫？;K-Koshiki-san. Are you okay?
# Koshiki;「水をかけられてしまいました。びしょ濡れです。;I was splashed with water. I'm soaking wet.
# <PNAME>;『みんな逃げているのに、どうして、古式さんだけ水がかかつてるの？;Everyone else is escaping, so why are you the only one who got splashed, Koshiki-san?
# Koshiki;「どうしてでしょう？;I wonder why?
# <PNAME>;『あつ、係の人がタオルを持つてきてくれたよ。（どうせまた、ボーッと見てたんだろうな⋯。）;Oh, the staff brought a towel. (She was probably just zoning out again...)
# <PNAME>;『それにしても、夏でよかつたね。;Anyway, it's a good thing it's summer.
# Koshiki;「そうですね。もう服も乾いてしまいました。;Yes, that's true. My clothes have already dried.
# <PNAME>;『そ、そうだね。（残念だぜ、さつきは下着が透けて見えそうだつたのにな⋯。）;Y-Yeah. (Too bad, they almost looked see-through earlier...)
# Koshiki;「よろしいですよ。参りましょう。;It's alright. Shall we go?
# Koshiki;「奇麗な花火ですねぇ。;Such beautiful fireworks.
# Tokens used: 2876
# Batch 400: Koshiki;「のぼりりゅうみだれ⋯？長くて覚えられません⋯。;“Nobori Ryuu Midare...? It's so long, I can't remember it..."
# Koshiki;「それでは、着替えて参ります。;“Then, I'll go and change."
# Koshiki;「何をしていらつしゃるのですか？;“What are you doing?"
# Koshiki;「奇麗な貝殻ですねぇ。ありがとうございます。;“It's a beautiful shell. Thank you."
# defect;「おう、俺様にぶつかつておきながら;“Oh, you bumped into me and yet
# <PNAME>;（それじゃ、カラオケ屋で、優美ちゃんを待つか。）;“Alright, let's wait for Yuumi-chan at the karaoke place."
# Koshiki;「よろしければ、―緒に植物園に行きませんか？;“If you'd like, would you go to the botanical garden with me?"
# <PNAME>;『弁論大会が始まるみたいだね。;“Looks like the speech contest is about to start."
# Koshiki;「今の弁論、早口でしたねぇ。;“The speech just now was fast, wasn't it?"
# <PNAME>;『えつ、そうだつた？普通だと思うけどなぁ。;“Huh, was it? I thought it was normal."
# Koshiki;「最初に話されたことを考えているうちにもう終わつてました。;“While I was thinking about the first thing that was said, it was already over."
# <PNAME>;『そ、そう⋯。たいした話じゃないから、聞かなくても同じだよ。;“Y-yeah... It's not a big deal, so it's the same even if you didn't listen."
# Koshiki;「そうなんですか。それなら、別に考えなくてもよかつたのですね。;“Is that so? Then, it was alright not to think about it."
# <PNAME>;『そ、そういうことになるのかなぁ⋯。そろそろ、帰ろうか？;“I-it seems that's what it means... Shall we head back soon?"
# Koshiki;「そうですね。そうしましょう。;“Yes, let's do that."
# Koshiki;「こんなにお花があつたら、素敵でしょうねぇ。;“So many flowers would be wonderful, wouldn't they?"
# Koshiki;「それは、いい考えですねぇ。;“That's a good idea."
# <PNAME>;（最近女の子の間で変な噂が流れているらしい⋯）;“Lately, it seems there's a strange rumor going around among the girls..."
# <PNAME>;『あれ、古式さん。その荷物は？;“Oh, Koshiki-san. What's that luggage?"
# Koshiki;「今、編み物をしていまして、どこでも編めるように、持つてきているんです。;“I'm knitting right now, so I brought it with me so I can knit anywhere."
# <PNAME>;『それじゃあ、ベンチにでも座つて、編み物してもいいよ。;“Then, you can sit on the bench and knit, if you'd like."
# Koshiki;「いいえ。そんな事をしては、失礼ですから。;“No, doing that would be impolite."
# <PNAME>;『編み物をしている女の子とお話するのつて、―度してみたかつたんだ。;“I've always wanted to talk to a girl who's knitting."
# Koshiki;「そうですか？それでは、失礼いたしまして。;“Is that so? Then, please excuse me."
# <PNAME>;『へぇ、器用だね。;“Wow, you're skillful."
# Koshiki;「好きなので、家でよく編んでますから。;“I like it, so I often knit at home."
# <PNAME>;『そうなんだ。誰かへのプレゼント？;“Is that so? Is it a present for someone?"
# Koshiki;「そうですねぇ。内緒にしておきます。;“Well, yes. I'll keep it a secret."
# <PNAME>;『そ、そう。でも、いい色だね。;“I see. But it's a nice color."
# Koshiki;「そうですか？気に入つてもらえて嬉しいです。;“Is that so? I'm glad you like it."
# Koshiki;「そうですか？気に入つてもらえて『嬉しい⋯？（どうしてだ？）;“Is that so? Happy you liked it...? (Why is that?)"
# Koshiki;「ここの編み方が、難しいんですよ。;“This part of the knitting is difficult, you know."
# <PNAME>;『古式さんに、編んでもらつた物をもらう人は幸せだね。;“The person who gets something knitted by Koshiki-san would be happy."
# Koshiki;「そうですか？それでは、頑張らないといけませんね。;“Is that so? Then I must do my best."
# <PNAME>;『本当に、器用だねぇ⋯。（もらえる人はいいなぁ⋯。）;“You're really skillful... (It's nice for the person who'll receive it...)"
# <PNAME>;（それじゃ、コンサート会場で、優美ちゃんを待つか。）;“Alright, let's wait for Yuumi-chan at the concert hall."
# Koshiki;「<PNAME>さんこんにちは。;“Hello, <PNAME>-san."
# Koshiki;「この前、公園で編んでいたセーターです。;“This is the sweater I was knitting at the park the other day."
# Koshiki;「色は気に入つてもらえたようでしたのでいいのですが。サイズはどうでしょう？;“It seems you liked the color, but how about the size?"
# <PNAME>;『どれどれ？大丈夫。ぴつたりだよ。;“Let's see? It's alright. It fits perfectly."
# Koshiki;「うまくできたみたいですね。どうですか？幸せになりましたか？;“Looks like it turned out well. How is it? Are you happy?"
# <PNAME>;『う、うん。もちろん最高に幸せだよ。;“Y-yeah. Of course, I'm extremely happy."
# Koshiki;「そうですか。それは、頑張つた甲斐がありました。;“Is that so? Then it was worth the effort."
# <PNAME>;『古式さん。本当に、これ貰つちゃつていいの？;“Koshiki-san. Are you sure it's okay for me to receive this?"
# Koshiki;「もちろんです。それでは、失礼いたします。;“Of course. Then, please excuse me."
# <PNAME>;（あぁ、幸せ。古式さんの心みたいに、あつたかいよ。）;“Ah, happiness. It's as warm as Koshiki-san's heart."
# Kiyokawa;「あつ、<PNICKNAME>あなたも招待されてたんだ。;“Ah, <PNICKNAME>, you were invited too."
# Fujisaki;「知つてるわよ。;“I know."
# <PNAME>;（やつた！清川さんと、優美ちゃんから、年賀状をもらつたラッキー。;“Yes! I got New Year's cards from Kiyokawa-san and Yuumi-chan. Lucky."
# none;おつ、中吉だ。;“Oh, medium luck."
# Tokens used: 509
# Batch 450: <PNAME>;『俺は中吉だつたよ。;I got a middle fortune.
# Koshiki;「そうですか。それでは、木に結びましょう。;I see. Well then, shall we tie it to the tree?
# Koshiki;「それでは、そろそろ中に入りましょうか。;Well then, shall we go inside soon?
# Koshiki;「そう言えば、私、滑れないのでした⋯。;Speaking of which, I can't skate...
# Koshiki;「そうですか。それでは、よろしくお願い致します。;I see. Well then, please take care of me.
# Kiyokawa;「何か、オリに閉じこめられて、可哀想だな。;They seem kind of pitiful being trapped in a cage.
# Kiyokawa;「何か、オリに閉じこめられて可哀想だな。;They seem kind of pitiful being trapped in a cage.
# Kiyokawa;「大自然の中で、走りまわりたいだろうね。;They must want to run around in the great outdoors.
#    Character name             Japanese text  \
# 0         <PNAME>     『いや、別に用はないんだけどなんとなくね。
# 1         <PNAME>  （ふつ、俺としたことが、少し迷つてしまつたぜ。）
# 2        Katagiri      「<PNICKNAME>。私に、何か用？
# 3         <PNAME>                     『‥‥‥。
# 4        Kisaragi             「もう、すつかり春ですね。
# ..            ...                       ...
# 3         Koshiki       「そう言えば、私、滑れないのでした⋯。
# 4         Koshiki  「そうですか。それでは、よろしくお願い致します。
# 5        Kiyokawa     「何か、オリに閉じこめられて、可哀想だな。
# 6        Kiyokawa      「何か、オリに閉じこめられて可哀想だな。
# 7        Kiyokawa      「大自然の中で、走りまわりたいだろうね。
#
#                                          English text
# 0   No, I don't really have anything to do, it's j...
# 1        Geez, I hesitated a bit for someone like me.
# 2         Do you need something from me, <PNICKNAME>?
# 3                                              ......
# 4           It's already completely spring, isn't it?
# ..                                                ...
# 3                 Speaking of which, I can't skate...
# 4           I see. Well then, please take care of me.
# 5   They seem kind of pitiful being trapped in a c...
# 6   They seem kind of pitiful being trapped in a c...
# 7   They must want to run around in the great outd...
#
# [458 rows x 3 columns]

# %%
csv3 = pd.concat((csv1, csv2_new_translated))
csv3 = csv3.drop_duplicates(subset=csv2_new.columns.values, keep='first')
csv3['English text'] = csv3['English text'].str.replace("\"", "").str.replace("“", "").str.replace("”", "")
csv3['English text'] = csv3['English text'].str.replace("Cordao", "Himoo").str.replace("Stringo", "Himoo").str.replace("String-o", "Himoo")
csv3['English text'] = csv3['English text'].str.replace("Furushiki", "Koshiki")
csv3['English text'] = csv3['English text'].str.replace("Mr. ", "").str.replace("Ms. ", "")
csv3['English text'] = csv3['English text'].str.replace("; ", "").str.strip()
csv3 = csv3[csv1.columns]
csv3 = csv3.dropna()

timestamp = pd.Timestamp.now().strftime("[%Y-%m-%d]")
csv3.to_csv(csv3_output_name, sep=";", index=False)
csv3
# Out:
#    Character name             Japanese text  \
# 0         <PNAME>          （今日は、伊集院さんとデートだ）
# 1         <PNAME>          （今日は、伊集院さんとデートだ）
# 2         <PNAME>    『伊集院さんのことについて知りたいんだけど。
# 3         <PNAME>             『よし、次は、伊集院とだ。
# 4         <PNAME>          『しばらく伊集院さんと話し込んだ
# ..            ...                       ...
# 3         Koshiki       「そう言えば、私、滑れないのでした⋯。
# 4         Koshiki  「そうですか。それでは、よろしくお願い致します。
# 5        Kiyokawa     「何か、オリに閉じこめられて、可哀想だな。
# 6        Kiyokawa      「何か、オリに閉じこめられて可哀想だな。
# 7        Kiyokawa      「大自然の中で、走りまわりたいだろうね。
#
#                                          English text
# 0               (I have a date with Ijuin-san today.)
# 1              (Today, I have a date with Ijuin-san.)
# 2               I would like to know about Ijuin-san.
# 3                  (Okay, next time, with Ijuin-san.)
# 4              (I talked with Ijuin-san for a while.)
# ..                                                ...
# 3                 Speaking of which, I can't skate...
# 4           I see. Well then, please take care of me.
# 5   They seem kind of pitiful being trapped in a c...
# 6   They seem kind of pitiful being trapped in a c...
# 7   They must want to run around in the great outd...
#
# [6526 rows x 3 columns]
